# %% [markdown]
# We make sure the export table names are generated through the dbt project. Just scan edge/node files.

# %%
import pathlib

WHERE_IS_DBT_PROJECT_SQLS = "../../omdb_manual_dataset/omdb_dbt_project/models/movie_info_graph/*.sql"

table_names = [f.name.split('.')[0] for f in pathlib.Path().glob(WHERE_IS_DBT_PROJECT_SQLS)]

WHERE_TO_EXPORT_CSV_FILES = 'C:/work/omdb_graphdb_article/neo4j_version/export_elt/'

p = pathlib.Path(WHERE_TO_EXPORT_CSV_FILES)
p.mkdir(exist_ok=True)

for csv_file in p.glob('*.gz'):
    print(csv_file)
    csv_file.unlink()
# Out:
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_category_has_name.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_category_has_parent.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_category_has_root.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_content_has_abstract.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_content_has_cast.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_content_has_category.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_content_has_content_alias.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_content_has_content_link.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_content_has_content_reference.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_content_has_country.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_content_has_keyword.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_content_has_person_link.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_content_has_trailer.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_episode_has_season.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_episode_has_series.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_job_has_cast.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_job_has_description.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_movie_has_movieseries.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_person_has_alias.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_person_has_cast.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_season_has_series.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\edge_series_has_movieseries.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\node_cast.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\node_category.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\node_category_name.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\node_character.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\node_content.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\node_content_abstract.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\node_content_alias.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\node_content_content_link.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\node_content_person_link.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\node_content_reference.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\node_content_trailer.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\node_image.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\node_job.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\node_job_description.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\node_person.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\node_person_alias.json.gz
# C:\work\omdb_graphdb_article\neo4j_version\export_elt\region_codes.json.gz

# %%
table_names
# Out:
# ['edge_category_has_name',
#  'edge_category_has_parent',
#  'edge_category_has_root',
#  'edge_content_has_abstract',
#  'edge_content_has_cast',
#  'edge_content_has_category',
#  'edge_content_has_content_alias',
#  'edge_content_has_content_link',
#  'edge_content_has_content_reference',
#  'edge_content_has_country',
#  'edge_content_has_keyword',
#  'edge_content_has_person_link',
#  'edge_content_has_trailer',
#  'edge_episode_has_season',
#  'edge_episode_has_series',
#  'edge_job_has_cast',
#  'edge_job_has_description',
#  'edge_movie_has_movieseries',
#  'edge_person_has_alias',
#  'edge_person_has_cast',
#  'edge_season_has_series',
#  'edge_series_has_movieseries',
#  'node_cast',
#  'node_category',
#  'node_category_name',
#  'node_character',
#  'node_content',
#  'node_content_abstract',
#  'node_content_alias',
#  'node_content_content_link',
#  'node_content_person_link',
#  'node_content_reference',
#  'node_content_trailer',
#  'node_image',
#  'node_job',
#  'node_job_description',
#  'node_person',
#  'node_person_alias']

# %%
# !python -m pip install pandas SQLAlchemy psycopg2-binary
# Out:
# Requirement already satisfied: pandas in c:\work\omdb_graphdb_article\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: SQLAlchemy in c:\work\omdb_graphdb_article\.venv\lib\site-packages (2.0.36)
# Requirement already satisfied: psycopg2-binary in c:\work\omdb_graphdb_article\.venv\lib\site-packages (2.9.10)
# Requirement already satisfied: numpy>=1.26.0 in c:\work\omdb_graphdb_article\.venv\lib\site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\work\omdb_graphdb_article\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\work\omdb_graphdb_article\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\work\omdb_graphdb_article\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\work\omdb_graphdb_article\.venv\lib\site-packages (from SQLAlchemy) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\work\omdb_graphdb_article\.venv\lib\site-packages (from SQLAlchemy) (3.1.1)
# Requirement already satisfied: six>=1.5 in c:\work\omdb_graphdb_article\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# We export to csv node/edge tables

# %%
from sqlalchemy import create_engine
import pandas as pd


engine = create_engine('postgresql://postgres:postgres@localhost:5432/postgres')

def drop_nulls(some_list):
    return [x for x in some_list if x is not None]

for table_name in table_names+['region_codes']:
    print(f"Exporting {table_name}")
    df = pd.read_sql_query(f'select * from dbt.{table_name}',con=engine)
    if table_name == 'node_person':
        df['birthday'] = df['birthday'].astype(str)
        df['deathday'] = df['deathday'].astype(str)
    if table_name == 'node_cast':
        df['roles'] = df['roles'].map(lambda x: drop_nulls(x))
    df.to_json(f"{WHERE_TO_EXPORT_CSV_FILES}/{table_name}.json.gz", orient='records', compression='gzip')

engine.dispose()
# Out:
# Exporting edge_category_has_name
# Exporting edge_category_has_parent
# Exporting edge_category_has_root
# Exporting edge_content_has_abstract
# Exporting edge_content_has_cast
# Exporting edge_content_has_category
# Exporting edge_content_has_content_alias
# Exporting edge_content_has_content_link
# Exporting edge_content_has_content_reference
# Exporting edge_content_has_country
# Exporting edge_content_has_keyword
# Exporting edge_content_has_person_link
# Exporting edge_content_has_trailer
# Exporting edge_episode_has_season
# Exporting edge_episode_has_series
# Exporting edge_job_has_cast
# Exporting edge_job_has_description
# Exporting edge_movie_has_movieseries
# Exporting edge_person_has_alias
# Exporting edge_person_has_cast
# Exporting edge_season_has_series
# Exporting edge_series_has_movieseries
# Exporting node_cast
# Exporting node_category
# Exporting node_category_name
# Exporting node_character
# Exporting node_content
# Exporting node_content_abstract
# Exporting node_content_alias
# Exporting node_content_content_link
# Exporting node_content_person_link
# Exporting node_content_reference
# Exporting node_content_trailer
# Exporting node_image
# Exporting node_job
# Exporting node_job_description
# Exporting node_person
# Exporting node_person_alias
# Exporting region_codes
